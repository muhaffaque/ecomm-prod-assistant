# %%
print("ok")
# Out:
# ok

# %%
import selenium

# %%
import undetected_chromedriver as uc

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\PRO\Data Science\Agentic AI Projects\ecomm-prod-assistant\venv\Scripts\python.exe

# %%
from langchain_astradb import AstraDBVectorStore
